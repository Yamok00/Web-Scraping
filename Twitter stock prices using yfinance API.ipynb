# %%
# importing required modules, yfinance=yahoo finance
import yfinance as yf
import pandas as pd

# %%
# create an object that allows us to access function to extract data

# %%
twt = yf.Ticker('TWTR') # ticker list from yahoo finance

# %%
# stock info
twt_info = twt.info

# %%
twt_info
# Out:
# {'zip': '94103',
#  'sector': 'Communication Services',
#  'fullTimeEmployees': 7500,
# ...

# %%
twt_info['country']
# Out:
# 'United States'

# %%
twt_info['fullTimeEmployees']
# Out:
# 7500

# %%
twt_info['state']
# Out:
# 'CA'

# %%
twt_info['city']
# Out:
# 'San Francisco'

# %% [markdown]
# Extracting share price

# %%
twt_share_price_data = twt.history(period='max')

# %%
twt_share_price_data.head()
# Out:
#                  Open       High        Low      Close     Volume  Dividends  \
# Date
# 2013-11-07  45.099998  50.090000  44.000000  44.900002  117701600          0
# 2013-11-08  45.930000  46.939999  40.689999  41.650002   27925300          0
# 2013-11-11  40.500000  43.000000  39.400002  42.900002   16113900          0
# 2013-11-12  43.660000  43.779999  41.830002  41.900002    6316700          0
# 2013-11-13  41.029999  42.869999  40.759998  42.599998    8688300          0
#
#             Stock Splits
# Date
# 2013-11-07             0
# 2013-11-08             0
# 2013-11-11             0
# 2013-11-12             0
# 2013-11-13             0

# %%
twt.get_earnings()
# Out:
#          Revenue    Earnings
# Year
# 2018  3042359000  1205596000
# 2019  3459329000  1465659000
# 2020  3716349000 -1135626000
# 2021  5077482000  -221409000

# %%
twt.financials
# Out:
#                                           2021-12-31    2020-12-31  \
# Research Development                    1246704000.0   873011000.0
# Effect Of Accounting Charges                    None          None
# Income Before Tax                       -411113000.0   -50939000.0
# Minority Interest                               None          None
# Net Income                              -221409000.0 -1135626000.0
# Selling General Administrative          1760306000.0  1450292000.0
# Gross Profit                            3279972000.0  2349961000.0
# Ebit                                     272962000.0    26658000.0
# Operating Income                         272962000.0    26658000.0
# Other Operating Expenses                        None          None
# Interest Expense                         -51186000.0  -152878000.0
# Extraordinary Items                             None          None
# Non Recurring                                   None          None
# ...

# %%
twt.quarterly_earnings
# Out:
#             Revenue   Earnings
# Quarter
# 3Q2021   1283817000 -536757000
# 4Q2021   1567220000  181694000
# 1Q2022   1200984000  513286000
# 2Q2022   1176660000 -270007000

# %%
twt_share_price_data.head()
# Out:
#                  Open       High        Low      Close     Volume  Dividends  \
# Date
# 2013-11-07  45.099998  50.090000  44.000000  44.900002  117701600          0
# 2013-11-08  45.930000  46.939999  40.689999  41.650002   27925300          0
# 2013-11-11  40.500000  43.000000  39.400002  42.900002   16113900          0
# 2013-11-12  43.660000  43.779999  41.830002  41.900002    6316700          0
# 2013-11-13  41.029999  42.869999  40.759998  42.599998    8688300          0
#
#             Stock Splits
# Date
# 2013-11-07             0
# 2013-11-08             0
# 2013-11-11             0
# 2013-11-12             0
# 2013-11-13             0

# %%
twt_share_price_data.reset_index(inplace=True)

# %%
# plot of twitter share open price till date
twt_share_price_data.plot(x='Date', y='Open', title='Twitter Share Price')
# Out:
# <AxesSubplot:title={'center':'Twitter Share Price'}, xlabel='Date'>

# %%
twt.recommendations
# Out:
#                                            Firm        To Grade From Grade  \
# Date
# 2013-10-07 16:00:00  SunTrust Robinson Humphrey             Buy
# 2013-10-28 08:11:59            Pivotal Research             Buy
# 2013-10-30 14:04:58                      Topeka             Buy
# 2013-11-04 08:23:43           Atlantic Equities      Overweight
# 2013-11-05 08:38:48                 CRT Capital             Buy
# ...                                         ...             ...        ...
# 2022-07-25 11:44:27                   Citigroup         Neutral
# 2022-07-25 12:46:15                 Cowen & Co.  Market Perform
# 2022-08-05 10:51:33                 Susquehanna         Neutral   Positive
# 2022-08-10 10:32:28                     Wedbush         Neutral
# 2022-08-24 11:45:34                  Rosenblatt         Neutral        Buy
#
#                     Action
# Date
# 2013-10-07 16:00:00   init
# 2013-10-28 08:11:59   init
# 2013-10-30 14:04:58   init
# 2013-11-04 08:23:43   init
# ...
